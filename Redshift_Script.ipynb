# %% [markdown]
# Crear la tabla

# %%
create table bankruptcy.public.dataset(
    Bankrupt integer, 
    ROAC_before_interest_and_depreciation_before_interest DOUBLE PRECISION,
    ROAA_before_interest_and__after_tax DOUBLE PRECISION,
    ROAB_before_interest_and_depreciation_after_tax DOUBLE PRECISION,
    Operating_Gross_Margin DOUBLE PRECISION,
    Realized_Sales_Gross_Margin DOUBLE PRECISION,
    Operating_Profit_Rate DOUBLE PRECISION,
    Pre_tax_net_Interest_Rate DOUBLE PRECISION,
    After_tax_net_Interest_Rate DOUBLE PRECISION,
    Non_industry_income_and_expenditurerevenue DOUBLE PRECISION,
    Continuous_interest_rate_after_tax DOUBLE PRECISION,
    Operating_Expense_Rate DOUBLE PRECISION,
    Research_and_development_expense_rate DOUBLE PRECISION,
    Cash_flow_rate DOUBLE PRECISION,
    Interest_bearing_debt_interest_rate DOUBLE PRECISION,
    Tax_rate_A DOUBLE PRECISION,
    Net_Value_Per_Share_B DOUBLE PRECISION,
    Net_Value_Per_Share_A DOUBLE PRECISION,
    Net_Value_Per_Share_C DOUBLE PRECISION,
    Persistent_EPS_in_the_Last_Four_Seasons DOUBLE PRECISION,
    Cash_Flow_Per_Share DOUBLE PRECISION,
    Revenue_Per_Share_Yuan_ DOUBLE PRECISION,
    Operating_Profit_Per_Share_Yuan_ DOUBLE PRECISION,
    Per_Share_Net_profit_before_tax_Yuan_ DOUBLE PRECISION,
    Realized_Sales_Gross_Profit_Growth_Rate DOUBLE PRECISION,
    Operating_Profit_Growth_Rate DOUBLE PRECISION,
    After_tax_Net_Profit_Growth_Rate DOUBLE PRECISION,
    Regular_Net_Profit_Growth_Rate DOUBLE PRECISION,
    Continuous_Net_Profit_Growth_Rate DOUBLE PRECISION,
    Total_Asset_Growth_Rate DOUBLE PRECISION,
    Net_Value_Growth_Rate DOUBLE PRECISION,
    Total_Asset_Return_Growth_Rate_Ratio DOUBLE PRECISION,
    Cash_Reinvestment_ DOUBLE PRECISION,
    Current_Ratio DOUBLE PRECISION,
    Quick_Ratio DOUBLE PRECISION,
    Interest_Expense_Ratio DOUBLE PRECISION,
    Total_debtTotal_net_worth DOUBLE PRECISION,
    Debt_ratio_ DOUBLE PRECISION,
    Net_worthAssets DOUBLE PRECISION,
    Long_term_fund_suitability_ratio_A DOUBLE PRECISION,
    Borrowing_dependency DOUBLE PRECISION,
    Contingent_liabilitiesNet_worth DOUBLE PRECISION,
    Operating_profitPaid_in_capital DOUBLE PRECISION,
    Net_profit_before_taxPaid_in_capital DOUBLE PRECISION,
    Inventory_and_accounts_receivableNet_value DOUBLE PRECISION,
    Total_Asset_Turnover DOUBLE PRECISION,
    Accounts_Receivable_Turnover DOUBLE PRECISION,
    Average_Collection_Days DOUBLE PRECISION,
    Inventory_Turnover_Rate_times DOUBLE PRECISION,
    Fixed_Assets_Turnover_Frequency DOUBLE PRECISION,
    Net_Worth_Turnover_Rate_times DOUBLE PRECISION,
    Revenue_per_person DOUBLE PRECISION,
    Operating_profit_per_person DOUBLE PRECISION,
    Allocation_rate_per_person DOUBLE PRECISION,
    Working_Capital_to_Total_Assets DOUBLE PRECISION,
    Quick_AssetsTotal_Assets DOUBLE PRECISION,
    Current_AssetsTotal_Assets DOUBLE PRECISION,
    CashTotal_Assets DOUBLE PRECISION,
    Quick_AssetsCurrent_Liability DOUBLE PRECISION,
    CashCurrent_Liability DOUBLE PRECISION,
    Current_Liability_to_Assets DOUBLE PRECISION,
    Operating_Funds_to_Liability DOUBLE PRECISION,
    InventoryWorking_Capital DOUBLE PRECISION,
    InventoryCurrent_Liability DOUBLE PRECISION,
    Current_LiabilitiesLiability DOUBLE PRECISION,
    Working_CapitalEquity DOUBLE PRECISION,
    Current_LiabilitiesEquity DOUBLE PRECISION,
    Long_term_Liability_to_Current_Assets DOUBLE PRECISION,
    Retained_Earnings_to_Total_Assets DOUBLE PRECISION,
    Total_incomeTotal_expense DOUBLE PRECISION,
    Total_expenseAssets DOUBLE PRECISION,
    Current_Asset_Turnover_Rate DOUBLE PRECISION,
    Quick_Asset_Turnover_Rate DOUBLE PRECISION,
    Working_capitcal_Turnover_Rate DOUBLE PRECISION,
    Cash_Turnover_Rate DOUBLE PRECISION,
    Cash_Flow_to_Sales DOUBLE PRECISION,
    Fixed_Assets_to_Assets DOUBLE PRECISION,
    Current_Liability_to_Liability DOUBLE PRECISION,
    Current_Liability_to_Equity DOUBLE PRECISION,
    Equity_to_Long_term_Liability DOUBLE PRECISION,
    Cash_Flow_to_Total_Assets DOUBLE PRECISION,
    Cash_Flow_to_Liability DOUBLE PRECISION,
    CFO_to_Assets DOUBLE PRECISION,
    Cash_Flow_to_Equity DOUBLE PRECISION,
    Current_Liability_to_Current_Assets DOUBLE PRECISION,
    Liability_Assets_Flag integer,
    Net_Income_to_Total_Assets DOUBLE PRECISION,
    Total_assets_to_GNP_price DOUBLE PRECISION,
    No_credit_Interval DOUBLE PRECISION,
    Gross_Profit_to_Sales DOUBLE PRECISION,
    Net_Income_to_Stockholders_Equity DOUBLE PRECISION,
    Liability_to_Equity DOUBLE PRECISION,
    Degree_of_Financial_Leverage_DFL DOUBLE PRECISION,
    Interest_Coverage_Ratio_Interest_expense_to_EBIT DOUBLE PRECISION,
    Net_Income_Flag integer,
    Equity_to_Liability DOUBLE PRECISION
    );

# %% [markdown]
# Traer data de s3

# %%
COPY dataset
FROM 's3://proyecto-integrador/Dataset/dataset_bankruptcy.csv'
CREDENTIALS 'aws_iam_role=arn:aws:iam::789486117121:role/LabRole'
FORMAT csv
DELIMITER ','
IGNOREHEADER 1;

# %%
SELECT
    *
FROM
    "bankruptcy"."public"."dataset";
